# %%
import pandas as pd

# %%
data = pd.read_json("chess_data_40183.jsonl", lines=True)

# %%
data.shape
# Out:
# (40183, 3)

# %%
# remove duplicates
data_no_dups = data.drop_duplicates()

# %%
data_no_dups.shape
# Out:
# (40183, 3)

# %% [markdown]
# No duplicates were found, so we can use the chess_data_40183 file for training!
